# %%
import os
import cv2

# %%
path = './images/RDR2 LIVE.jpg'

# %%
path
# Out:
# './images/RDR2 LIVE.jpg'

# %%
img=cv2.imread(path)

# %%
if img is None:
    print("Image not loaded. Check the path or filename.")
else:
    print("Image loaded successfully!")
# Out:
# Image loaded successfully!

# %%
cv2.imwrite(os.path.join('.','images','rr.jpg'),img)
# Out:
# True

# %%
cv2.imshow('frame',img)
cv2.waitKey(0)
# Out:
# -1

# %%
vid= os.path.join('.','video','hii.mp4')

# %%
vid
# Out:
# '.\\video\\hii.mp4'

# %%
v=cv2.VideoCapture(vid)

# %%
ret=True

while ret:
    ret,frame=v.read()
    if ret:
        cv2.imshow('fortnite',frame)
        cv2.waitKey(16)
v.release()
cv2.destroyAllWindows()

# %% [markdown]
# webcam is heree

# %%
web=cv2.VideoCapture(0)
while True:
    _,frame=web.read()
   
    cv2.imshow('web',frame)
    if cv2.waitKey(40) & 0XFF == ord('q'):
        break

web.release()
cv2.destroyAllWindows()

# %%
img=cv2.imread(os.path.join('.','images','rr.jpg'))

# %%
cv2.imshow('hi',img)
cv2.waitKey(0)
# Out:
# -1

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
i=cv2.resize(img,(640,640))

# %%
i.shape
# Out:
# (640, 640, 3)

# %%
cv2.imshow('i',i)
cv2.waitKey(0)
# Out:
# -1

# %%
crop=i[220:640,120:640]

# %%
crop.shape
# Out:
# (420, 520, 3)

# %%
cv2.imshow('hi',crop)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# colorspaces
# BGR-blue green red
# RGB-Red green blue
# Gray- Black and white

# %%
color=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
cv2.imshow('hi',color)
cv2.waitKey(0)
# Out:
# -1

# %%
color1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('hi',color1)
cv2.waitKey(0)
# Out:
# -1

# %%
color2=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2.imshow('hi',color2)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# BLUR
#
# blur can also be used to reduce the noise in images

# %%
blur=cv2.blur(img,(7,7))
gaussian=cv2.GaussianBlur(img,(7,7),5)
median=cv2.medianBlur(img,7)
cv2.imshow('classic',blur)
cv2.imshow('gaussian',gaussian)
cv2.imshow('median',median)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# threshholding

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

ret,trash=cv2.threshold(img,80,255,cv2.THRESH_BINARY)
cv2.imshow('trash',trash)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\Kaila\Open_CV_Hands_On\opencv.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kaila/Open_CV_Hands_On/opencv.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       <a href='vscode-notebook-cell:/c%3A/Users/Kaila/Open_CV_Hands_On/opencv.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> ret,trash=cv2.threshold(img,80,255,cv2.THRESH_BINARY)
#       <a href='vscode-notebook-cell:/c%3A/Users/Kaila/Open_CV_Hands_On/opencv.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a> cv2.imshow('trash',trash)
#
# error: OpenCV(4.11.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-15:Bad number of channels) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0x34dd5b3e::Set<1,-1,-1>,struct cv::impl::A0x34dd5b3e::Set<0,2,5>,4>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %%
img=cv2.blur(img,(8,8))

# %%
ret,trash=cv2.threshold(img,80,255,cv2.THRESH_BINARY)
cv2.imshow('trash',trash)
cv2.waitKey(0)
# Out:
# -1
